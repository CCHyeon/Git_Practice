# %% [markdown]
# # Dictionary

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남'}
people_info_list=[{'성':'홍', '이름':'길동', '직장':'강남'}, {'성':'막', '이름':'걸리', '직장':'강남'}]
len(people_info)
len(people_info_list[0])
# Out:
# 3

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남'}

type(people_info.keys())
# Out:
# dict_keys

# %%
key_list = list(people_info.keys())
type(key_list)
# Out:
# list

# %%
list(people_info.keys())[1]
# Out:
# '이름'

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남'}

people_info['취미'] = '테니스'

print(people_info)
# Out:
# {'성': '홍', '이름': '길동', '직장': '강남', '취미': '테니스'}

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남'}

people_info['이름'] ='당무'

print(people_info)
# Out:
# {'성': '홍', '이름': '당무', '직장': '강남'}

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}

del people_info['취미']

print(people_info)b
# Out:
# {'성': '홍', '이름': '길동', '직장': '강남'}

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}

#KeyError: '주소' : 없는 키 값을 호출하면 에러
#del people_info['주소']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-d409ab082acc> in <module>
#       1 people_info = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}
#       2
# ----> 3 del people_info['주소']
#
# KeyError: '주소'

# %%
people_info = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}

'성' not in people_info
# Out:
# False

# %%
people_info_1 = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}
people_info_2 = {'성':'김', '이름':'길동', '직장':'강남', '취미': '테니스'}

people_info_1 == people_info_2
# Out:
# False

# %%
people_info_1 = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}
people_info_2 = {'성':'김', '이름':'길동', '직장':'강남', '취미': '테니스'}

people = []

people.append(people_info_1)
people.append(people_info_2)

print(people)
# Out:
# [{'성': '홍', '이름': '길동', '직장': '강남', '취미': '테니스'}, {'성': '김', '이름': '길동', '직장': '강남', '취미': '테니스'}]

# %%
people_info_1 = {'성':'홍', '이름':'길동', '직장':'강남', '취미': '테니스'}

people_info_1.clear()

people_info_1
# Out:
# {}
