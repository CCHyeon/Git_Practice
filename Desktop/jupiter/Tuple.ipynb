# %%
tuple_data_1 = (1,2,3,4)
print(tuple_data_1[1])
print(tuple_data_1[1:])
# Out:
# 2
# (2, 3, 4)

# %%
tuple_data_1 = (1,2,3,4,4,4,4)
tuple_data_1.count(2)
# Out:
# 1

# %%
tuple_data_1 = (1,2,3,4,4,4,4)
tuple_data_2 = (2,3,4,5,6,7,4)
tuple_data_3 = tuple_data_1*tuple_data_2
print(tuple_data_3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b02f8fff8405> in <module>
#       1 tuple_data_1 = (1,2,3,4,4,4,4)
#       2 tuple_data_2 = (2,3,4,5,6,7,4)
# ----> 3 tuple_data_3 = tuple_data_1*tuple_data_2
#       4 print(tuple_data_3)
#
# TypeError: can't multiply sequence by non-int of type 'tuple'
